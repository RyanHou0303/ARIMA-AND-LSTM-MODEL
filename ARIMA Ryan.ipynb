# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ticker = 'AI'
c3ai_data = yf.Ticker(ticker)

# %%
historical_data = c3ai_data.history(period='5y')

# %%
historical_data
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2020-12-09 00:00:00-05:00  100.000000  115.000000   90.029999   92.489998
# 2020-12-10 00:00:00-05:00   99.480003  131.746002   96.000000  130.000000
# 2020-12-11 00:00:00-05:00  123.820000  133.000000  116.000000  119.580002
# 2020-12-14 00:00:00-05:00  122.160004  123.830002  100.660004  102.360001
# 2020-12-15 00:00:00-05:00  104.570000  109.889999   98.099998  102.000000
# ...                               ...         ...         ...         ...
# 2024-08-06 00:00:00-04:00   24.190001   24.299999   23.613001   23.900000
# 2024-08-07 00:00:00-04:00   24.490000   24.900000   23.340000   23.400000
# 2024-08-08 00:00:00-04:00   23.889999   24.959999   23.530001   24.850000
# 2024-08-09 00:00:00-04:00   24.969999   25.240000   24.700001   24.950001
# 2024-08-12 00:00:00-04:00   25.000000   25.000000   24.379999   24.600000
#
#                              Volume  Dividends  Stock Splits
# Date
# ...

# %%
historical_data.head()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2020-12-09 00:00:00-05:00  100.000000  115.000000   90.029999   92.489998
# 2020-12-10 00:00:00-05:00   99.480003  131.746002   96.000000  130.000000
# 2020-12-11 00:00:00-05:00  123.820000  133.000000  116.000000  119.580002
# 2020-12-14 00:00:00-05:00  122.160004  123.830002  100.660004  102.360001
# 2020-12-15 00:00:00-05:00  104.570000  109.889999   98.099998  102.000000
#
#                              Volume  Dividends  Stock Splits
# Date
# 2020-12-09 00:00:00-05:00  24805600        0.0           0.0
# 2020-12-10 00:00:00-05:00  22839500        0.0           0.0
# 2020-12-11 00:00:00-05:00  11758600        0.0           0.0
# 2020-12-14 00:00:00-05:00   8197500        0.0           0.0
# 2020-12-15 00:00:00-05:00   5715300        0.0           0.0

# %%
ticker = "AI"
start_date = "2022-01-01"
end_date = "2024-08-01"
asset_data = yf.download(ticker, start=start_date, end=end_date)
asset_data.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2022-01-03  31.490000  32.360001  30.430000  32.299999  32.299999  2767100
# 2022-01-04  32.349998  32.349998  29.400000  30.820000  30.820000  5141400
# 2022-01-05  30.280001  31.469999  29.120001  29.330000  29.330000  3629100
# 2022-01-06  29.000000  30.370001  28.350000  29.610001  29.610001  2419500
# 2022-01-07  29.709999  30.969999  29.650000  29.940001  29.940001  2299200

# %%
asset_data_cleaned = asset_data.dropna()
asset_data = asset_data_cleaned.drop_duplicates()
asset_data
# Out:
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2022-01-03  31.490000  32.360001  30.430000  32.299999  32.299999  2767100
# 2022-01-04  32.349998  32.349998  29.400000  30.820000  30.820000  5141400
# 2022-01-05  30.280001  31.469999  29.120001  29.330000  29.330000  3629100
# 2022-01-06  29.000000  30.370001  28.350000  29.610001  29.610001  2419500
# 2022-01-07  29.709999  30.969999  29.650000  29.940001  29.940001  2299200
# ...               ...        ...        ...        ...        ...      ...
# 2024-07-25  26.219999  27.629999  25.799999  26.840000  26.840000  3693400
# 2024-07-26  27.639999  27.950001  26.950001  27.730000  27.730000  2758500
# 2024-07-29  27.930000  28.049999  27.120001  27.400000  27.400000  1902300
# 2024-07-30  27.510000  27.930000  25.920000  26.590000  26.590000  3291300
# 2024-07-31  27.180000  27.590000  26.674999  26.750000  26.750000  3173700
#
# [647 rows x 6 columns]

# %%
data = asset_data[['Adj Close']].copy()

# %%
data
# Out:
#             Adj Close
# Date
# 2022-01-03  32.299999
# 2022-01-04  30.820000
# 2022-01-05  29.330000
# 2022-01-06  29.610001
# 2022-01-07  29.940001
# ...               ...
# 2024-07-25  26.840000
# 2024-07-26  27.730000
# 2024-07-29  27.400000
# 2024-07-30  26.590000
# 2024-07-31  26.750000
#
# [647 rows x 1 columns]

# %%
def plot():
    sns.set(rc={'figure.figsize' : (16,8)})
    data.plot(label = f"{label_text}")
    plt.title(f"{title_text}",color = 'black',fontsize = 15)
    plt.ylabel('Stock Price(p)',color = 'black', fontsize = 15)
    plt.legend()

# %%
title_text = "adjusted closed price"
label_text = "adj_closed"

# %%
plot()

# %% [markdown]
# check seasonallity

# %%
season_diff = data.diff(periods = 90)[90:]

# %%
season_diff
# Out:
#             Adj Close
# Date
# 2022-05-12 -17.739999
# 2022-05-13 -13.039999
# 2022-05-16 -12.590000
# 2022-05-17 -12.120001
# 2022-05-18 -12.790001
# ...               ...
# 2024-07-25  -2.080000
# 2024-07-26  -1.320000
# 2024-07-29  -0.890001
# 2024-07-30  -2.059999
# 2024-07-31  -1.629999
#
# [557 rows x 1 columns]

# %%
plt.figure(figsize=(16,8))

# %%
season_diff.index
# Out:
# DatetimeIndex(['2022-05-12', '2022-05-13', '2022-05-16', '2022-05-17',
#                '2022-05-18', '2022-05-19', '2022-05-20', '2022-05-23',
#                '2022-05-24', '2022-05-25',
#                ...
#                '2024-07-18', '2024-07-19', '2024-07-22', '2024-07-23',
#                '2024-07-24', '2024-07-25', '2024-07-26', '2024-07-29',
#                '2024-07-30', '2024-07-31'],
#               dtype='datetime64[ns]', name='Date', length=557, freq=None)

# %%
plt.plot(season_diff.index,season_diff,label="year differenced")

# %%
plt.plot(season_diff.index,season_diff, label = 'seasonal difference')
plt.plot(data.index,data['Adj Close'], label = 'Original')
plt.title("Difference",color = 'black', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Difference')

# %% [markdown]
# a strong seasonal trend is unlikely

# %% [markdown]
# stationary
# ADF test

# %%
data
# Out:
#             Adj Close
# Date
# 2022-01-03  32.299999
# 2022-01-04  30.820000
# 2022-01-05  29.330000
# 2022-01-06  29.610001
# 2022-01-07  29.940001
# ...               ...
# 2024-07-25  26.840000
# 2024-07-26  27.730000
# 2024-07-29  27.400000
# 2024-07-30  26.590000
# 2024-07-31  26.750000
#
# [647 rows x 1 columns]

# %%
from statsmodels.tsa.stattools import adfuller

# %%
adf = adfuller(data)

# %%
print(f'adf statistic:{adf[0]}')
print(f'p-value:{adf[1]}')
adf
# Out:
# adf statistic:-2.210760183821492
# p-value:0.20236333582256033
# (-2.210760183821492,
#  0.20236333582256033,
#  3,
#  643,
#  {'1%': -3.440560883168159,
#   '5%': -2.8660454146233434,
#   '10%': -2.569169329058723},
#  2210.8763476359945)

# %% [markdown]
# p-value is greater than the significance level of 0.05 and the ADF statistic is higher than any of the critical values,

# %% [markdown]
# non stationary

# %%
diff1 = data.diff().dropna()

# %%
diff1
# Out:
#             Adj Close
# Date
# 2022-01-04  -1.480000
# 2022-01-05  -1.490000
# 2022-01-06   0.280001
# 2022-01-07   0.330000
# 2022-01-10  -0.400000
# ...               ...
# 2024-07-25   0.380001
# 2024-07-26   0.889999
# 2024-07-29  -0.330000
# 2024-07-30  -0.809999
# 2024-07-31   0.160000
#
# [646 rows x 1 columns]

# %%
import statsmodels.tsa.api as smt
from statsmodels.graphics.tsaplots import plot_acf

# %%
def diff1_plot(y, lags=None, figsize=(12, 4)):
    plt.style.use('seaborn')
    fig = plt.figure(figsize=figsize)
    layout = (1,2)
    ax1 = plt.subplot2grid(layout, (0,0))
    acf_ax = plt.subplot2grid(layout, (0,1))

    y.plot(ax=ax1)
    ax1.set_title('Difference once')
    smt.graphics.plot_acf(y, lags=lags, ax=acf_ax)
    plt.tight_layout()
        
diff1_plot(diff1, lags=30)
# Out:
# C:\Users\14253\AppData\Local\Temp\ipykernel_24680\4247941100.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
from pmdarima.arima.utils import ndiffs

# %%
ndiffs(data, test = "adf")
# Out:
# 1

# %%
import statsmodels.tsa.api as smt
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.tsa.stattools import coint
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %% [markdown]
# pacf is useful to determine the order of AR(p) process, it only describe the relationship between an observation and its lag

# %% [markdown]
# we have that only one difference is needed

# %%
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_pacf

def pacf_plot(y, lags=30, figsize=(12, 4), style='seaborn'):
    """
   

    y : pandas Series
        
    lags : int, optional
        
    figsize : tuple, optional
       
    style : str, optional
       
    """
    
    plt.style.use(style)
    
   
    fig, axes = plt.subplots(1, 2, figsize=figsize)
    
  
    y.plot(ax=axes[0])
    axes[0].set_title('Difference once')
    
    
    plot_pacf(y, lags=lags, ax=axes[1])
    
   
    plt.tight_layout()
    plt.show()


pacf_plot(diff1)
# Out:
# C:\Users\14253\AppData\Local\Temp\ipykernel_24680\534619031.py:19: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use(style)

# %% [markdown]
# pacf lag3 is below the band , so pacf coefficient are not significatn, so autoregressive process of order 3

# %% [markdown]
# q, # of  lagged forecast error used to predict future value, reduce the noice,

# %%
        
diff1_plot(diff1, lags=30)
# Out:
# C:\Users\14253\AppData\Local\Temp\ipykernel_24680\4247941100.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
result2 = adfuller(data)
print(f'ADF Statistic: {result2[0]}')
print(f'p-value: {result2[1]}')
for key, value in result2[4].items():
    print('Critial Values:')
    print(f'   {key}, {value}')
# Out:
# ADF Statistic: -2.210760183821492
# p-value: 0.20236333582256033
# Critial Values:
#    1%, -3.440560883168159
# Critial Values:
#    5%, -2.8660454146233434
# Critial Values:
#    10%, -2.569169329058723

# %%
diff1 = data.diff().dropna()

# %%
diff1
# Out:
#             Adj Close
# Date
# 2022-01-04  -1.480000
# 2022-01-05  -1.490000
# 2022-01-06   0.280001
# 2022-01-07   0.330000
# 2022-01-10  -0.400000
# ...               ...
# 2024-07-25   0.380001
# 2024-07-26   0.889999
# 2024-07-29  -0.330000
# 2024-07-30  -0.809999
# 2024-07-31   0.160000
#
# [646 rows x 1 columns]

# %%
result2 = adfuller(diff1)
print(f'ADF Statistic: {result2[0]}')
print(f'p-value: {result2[1]}')
for key, value in result2[4].items():
    print('Critial Values:')
    print(f'   {key}, {value}')
# Out:
# ADF Statistic: -17.19190473724228
# p-value: 6.54398655138998e-30
# Critial Values:
#    1%, -3.440560883168159
# Critial Values:
#    5%, -2.8660454146233434
# Critial Values:
#    10%, -2.569169329058723

# %% [markdown]
# ADF统计量是检验统计量。其绝对值越大，表明时间序列越有可能是平稳的。p值是用于判断时间序列是否平稳的一个指标。通常，如果p值小于0.05，则可以拒绝原假设（即时间序列存在单位根，不是平稳的），认为时间序列是平稳的。在这个例子中，p值非常小，远小于0.05，因此我们可以认为时间序列是平稳的

# %%
model = ARIMA(data, order=(3, 1, 3))
result = model.fit()
print(result.summary())
# Out:
# D:\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# D:\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# D:\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ...
# Dep. Variable:              Adj Close   No. Observations:                  647
# Model:                 ARIMA(3, 1, 3)   Log Likelihood               -1132.818
# Date:                Mon, 12 Aug 2024   AIC                           2279.637
# ...

# %%
from statsmodels.tsa.arima.model import ARIMA

# %%
model = ARIMA(data, order=(3, 1, 3))
result = model.fit()
print(result.summary())
# Out:
# D:\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# D:\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# D:\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ...
# Dep. Variable:              Adj Close   No. Observations:                  647
# Model:                 ARIMA(3, 1, 3)   Log Likelihood               -1132.818
# Date:                Mon, 12 Aug 2024   AIC                           2279.637
# ...

# %%
residuals = pd.DataFrame(result.resid)
residuals.plot();

# %%
from tqdm.notebook import tqdm
from statsmodels.tsa.statespace.sarimax import SARIMAX
def optimise_ARIMA(order_list, exog):
   
 
    results = [[order, SARIMAX(exog, order=order).fit(disp=0).aic] 
               for order in tqdm(order_list) 
               if SARIMAX(exog, order=order).fit(disp=0).aic]
    
  
    result_df = pd.DataFrame(results, columns=['(p, d, q)', 'AIC'])
    
  
    result_df = result_df.sort_values(by='AIC').reset_index(drop=True)

    return result_df

# %%
from itertools import product
# Parameters to iterate through
ps = range(0, 8, 1)
d = 1
qs = range(0, 8, 1)

# Create a list with all possible combination of parameters
parameters = product(ps, qs)
parameters_list = list(parameters)

order_list = []

for each in parameters_list:
    each = list(each)
    each.insert(1, 1)
    each = tuple(each)
    order_list.append(each)

# %%
result_df = optimise_ARIMA(order_list, exog=data['Adj Close'])
# Out:
#   0%|          | 0/64 [00:00<?, ?it/s]
# D:\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# D:\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# D:\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# D:\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# ...

# %%
result_df
# Out:
#     (p, d, q)          AIC
# 0   (7, 1, 6)  2274.195759
# 1   (2, 1, 5)  2274.311075
# 2   (7, 1, 4)  2275.597821
# 3   (0, 1, 3)  2275.854006
# 4   (3, 1, 0)  2276.190073
# ..        ...          ...
# 59  (7, 1, 7)  2286.128631
# 60  (0, 1, 1)  2286.864445
# 61  (0, 1, 0)  2287.274324
# 62  (1, 1, 0)  2287.295407
# 63  (1, 1, 1)  2287.988111
#
# [64 rows x 2 columns]

# %%
# Fit and print a summary of the best model, which is ARIMA (4,1,4)

best_model = ARIMA(data, order=(7, 1, 4)).fit()
print(best_model.summary())
# Out:
# D:\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# D:\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# D:\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# D:\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# ...

# %% [markdown]
# check white noise, residual, ideally, no autocorrelation, run Ljung-Box, null hypothesis: no autocorrelation, if p value smaller than 0.05, reject null hypothesis, if >0.05, fail to reject null hypothesiss

# %%
from statsmodels.stats.diagnostic import acorr_ljungbox
ljung_box, p_value = acorr_ljungbox(best_model.resid)
print(f'Ljung-Box test: {ljung_box[:10]}')
# Out:
# Ljung-Box test: lb_stat

# %%
ljung_box, p_value = acorr_ljungbox(best_model.resid)

print(f'Ljung-Box test: {ljung_box[:10]}')
print(f'p-value: {p_value[:10]}')
# Out:
# Ljung-Box test: lb_stat
# p-value: lb_pvalue

# %%
ljung_box_results = acorr_ljungbox(residuals, lags=10)

# %%
ljung_box = ljung_box_results['lb_stat']
p_value = ljung_box_results['lb_pvalue']
ljung_box
# Out:
# 1     0.268818
# 2     0.507818
# 3     0.527886
# 4     0.538961
# 5     0.543995
# 6     0.597705
# 7     0.613334
# 8     2.125499
# 9     2.223663
# 10    2.343521
# Name: lb_stat, dtype: float64

# %% [markdown]
# 所有p值都大于0.05，则表明模型残差在前10个滞后阶数上没有显著的自相关性，说明模型拟合良好。

# %%
start = len(data)  
end = start + 50   


predictions = best_model.get_forecast(steps=50)
predicted_mean = predictions.predicted_mean
conf_int = predictions.conf_int()


predicted_mean.index = pd.date_range(start=data.index[-1], periods=51, freq='D')[1:]
conf_int.index = pd.date_range(start=data.index[-1], periods=51, freq='D')[1:]
# Out:
# D:\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# D:\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %%
forecast_steps = 50
forecast = best_model.get_forecast(steps=forecast_steps)
predicted_mean = forecast.predicted_mean
conf_int = forecast.conf_int()


next_day_index = pd.date_range(start=data.index[-1], periods=forecast_steps+1, freq='D')[1:]

predicted_mean.index = next_day_index
conf_int.index = next_day_index


print(f"Next day's predicted stock price: {predicted_mean.iloc[0]}")
print(f"95% confidence interval: {conf_int.iloc[0].values}")


plt.figure(figsize=(16, 8))


plt.plot(data.index, data, label='Observed')


plt.plot(predicted_mean.index, predicted_mean, color='red', marker='o', label='Forecast')


plt.fill_between(conf_int.index, 
                 conf_int.iloc[:, 0], 
                 conf_int.iloc[:, 1], color='pink', alpha=0.3)


plt.legend()
plt.title('Forecast vs Observed')
plt.xlabel('Date')
plt.ylabel('Stock Price')


plt.show()
# Out:
# Next day's predicted stock price: 27.08657211484751
# 95% confidence interval: [24.3755492  29.79759503]
# D:\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
import pandas as pd
import matplotlib.pyplot as plt


forecast_steps = 50
forecast = best_model.get_forecast(steps=forecast_steps)
predicted_mean = forecast.predicted_mean
conf_int = forecast.conf_int()


next_day_index = pd.date_range(start=data.index[-1], periods=forecast_steps+1, freq='D')[1:]


predicted_mean.index = next_day_index
conf_int.index = next_day_index


print(f"Next day's predicted stock price: {predicted_mean.iloc[0]}")
print(f"95% confidence interval: {conf_int.iloc[0].values}")


plt.figure(figsize=(14, 8))


plt.plot(data.index, data, label='Observed', color='blue', linewidth=2)


plt.plot(predicted_mean.index, predicted_mean, color='red', marker='o', linestyle='-', label='Forecast', linewidth=2, markersize=5)


plt.fill_between(conf_int.index, 
                 conf_int.iloc[:, 0], 
                 conf_int.iloc[:, 1], 
                 color='pink', alpha=0.3, label='95% Confidence Interval')


plt.title('Forecast vs Observed', fontsize=18)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Stock Price', fontsize=14)


plt.legend(loc='upper right', fontsize=12)


plt.grid(visible=True, color='gray', linestyle='--', linewidth=0.5)
plt.tight_layout()


plt.show()
# Out:
# D:\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# Next day's predicted stock price: 27.08657211484751
# 95% confidence interval: [24.3755492  29.79759503]

# %%
import pandas as pd
import matplotlib.pyplot as plt

forecast_steps = 50
forecast = best_model.get_forecast(steps=forecast_steps)
predicted_mean = forecast.predicted_mean
conf_int = forecast.conf_int()


next_day_index = pd.date_range(start=data.index[-1], periods=forecast_steps+1, freq='D')[1:]


predicted_mean.index = next_day_index
conf_int.index = next_day_index


print(f"Next day's predicted stock price: {predicted_mean.iloc[0]}")
print(f"95% confidence interval: {conf_int.iloc[0].values}")


plt.figure(figsize=(14, 8))


plt.plot(data.index, data, label='Observed', color='blue', linewidth=2)


plt.plot(predicted_mean.index, predicted_mean, color='red', marker='o', linestyle='--', 
         label='Forecast', linewidth=3, markersize=8)


plt.fill_between(conf_int.index, 
                 conf_int.iloc[:, 0], 
                 conf_int.iloc[:, 1], 
                 color='pink', alpha=0.3, label='95% Confidence Interval')


plt.title('Forecast vs Observed', fontsize=18)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Stock Price', fontsize=14)


plt.legend(loc='upper left', bbox_to_anchor=(1, 1), fontsize=12)


plt.grid(visible=True, color='gray', linestyle='--', linewidth=0.5)
plt.tight_layout()


plt.show()
# Out:
# D:\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# Next day's predicted stock price: 27.08657211484751
# 95% confidence interval: [24.3755492  29.79759503]

# %%
import pandas as pd
import matplotlib.pyplot as plt

forecast_steps = 20
forecast = best_model.get_forecast(steps=forecast_steps)
predicted_mean = forecast.predicted_mean
conf_int = forecast.conf_int()

next_day_index = pd.date_range(start=data.index[-1], periods=forecast_steps+1, freq='D')[1:]

predicted_mean.index = next_day_index
conf_int.index = next_day_index

print(f"Next day's predicted stock price: {predicted_mean.iloc[0]}")
print(f"95% confidence interval: {conf_int.iloc[0].values}")

plt.figure(figsize=(14, 8))


plt.plot(data.index, data, label='Observed', color='blue', linewidth=2)

plt.plot(predicted_mean.index, predicted_mean, color='red', marker='o', linestyle='--', 
         label='Forecast', linewidth=3, markersize=8)

plt.fill_between(conf_int.index, 
                 conf_int.iloc[:, 0], 
                 conf_int.iloc[:, 1], 
                 color='pink', alpha=0.3, label='95% Confidence Interval')


plt.xlim([data.index[-50], next_day_index[-1]])  
plt.ylim([min(conf_int.iloc[:, 0]) * 0.95, max(conf_int.iloc[:, 1]) * 1.05])


plt.title('Focused Forecast vs Observed', fontsize=18)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Stock Price', fontsize=14)


plt.legend(loc='upper left', bbox_to_anchor=(1, 1), fontsize=12)
plt.grid(visible=True, color='gray', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()
# Out:
# D:\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# Next day's predicted stock price: 27.08657211484751
# 95% confidence interval: [24.3755492  29.79759503]

# %%
import pandas as pd
import matplotlib.pyplot as plt


forecast_steps = 20
forecast = best_model.get_forecast(steps=forecast_steps)
predicted_mean = forecast.predicted_mean
conf_int = forecast.conf_int()


next_day_index = pd.date_range(start=data.index[-1], periods=forecast_steps+1, freq='D')[1:]


predicted_mean.index = next_day_index
conf_int.index = next_day_index


print(f"Next day's predicted stock price: {predicted_mean.iloc[0]}")
print(f"95% confidence interval: {conf_int.iloc[0].values}")


plt.figure(figsize=(14, 8))


plt.plot(data.index[-100:], data[-100:], label='Observed', color='blue', linewidth=2)


plt.plot(predicted_mean.index, predicted_mean, color='red', marker='o', linestyle='--', 
         label='Forecast', linewidth=3, markersize=8)


plt.fill_between(conf_int.index, 
                 conf_int.iloc[:, 0], 
                 conf_int.iloc[:, 1], 
                 color='pink', alpha=0.3, label='95% Confidence Interval')


plt.xlim([data.index[-100], next_day_index[-1]])  
plt.ylim([min(conf_int.iloc[:, 0]) * 0.95, max(conf_int.iloc[:, 1]) * 1.05])

plt.title('Expanded Historical Data with Focused Forecast', fontsize=18)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Stock Price', fontsize=14)


plt.legend(loc='upper left', bbox_to_anchor=(1, 1), fontsize=12)


plt.grid(visible=True, color='gray', linestyle='--', linewidth=0.5)
plt.tight_layout()


plt.show()
# Out:
# D:\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# Next day's predicted stock price: 27.08657211484751
# 95% confidence interval: [24.3755492  29.79759503]
